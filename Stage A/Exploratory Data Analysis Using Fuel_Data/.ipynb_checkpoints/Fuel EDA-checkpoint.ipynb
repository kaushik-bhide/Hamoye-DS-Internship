# %% [markdown]
# # Fuel EDA

# %%
##Importing the Data 
import pandas as pd
fuel = pd.read_csv('fuel_data.csv')

# %%
##Printing the Head Values
fuel.head()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %%
### Getting the Glimpse of the Dataset
fuel.sample(5)
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 27034  f1_fuel_2016_12_177_0_10               177         2016
# 4388    f1_fuel_1997_12_174_0_4               174         1997
# 12694   f1_fuel_2004_12_194_5_5               194         2004
# 21896   f1_fuel_2012_12_186_6_2               186         2012
# 11062    f1_fuel_2003_12_74_0_4                74         2003
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 27034               meramec                coal       ton        1118582.0
# 4388        tnp one, unit 2                 gas       mcf          81776.0
# 12694  s fond du lac unit 2                 oil       bbl            434.0
# 21896              rosemary                 gas       mcf         851185.0
# 11062        harding street                coal       ton        1781034.0
#
#        fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 27034            17.218000                     39.068
# ...

# %%
### Printing the Info
print("Info",fuel.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29523 entries, 0 to 29522
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     29523 non-null  object
#  1   utility_id_ferc1              29523 non-null  int64
#  2   report_year                   29523 non-null  int64
#  3   plant_name_ferc1              29523 non-null  object
#  4   fuel_type_code_pudl           29523 non-null  object
#  5   fuel_unit                     29343 non-null  object
#  6   fuel_qty_burned               29523 non-null  float64
#  7   fuel_mmbtu_per_unit           29523 non-null  float64
#  8   fuel_cost_per_unit_burned     29523 non-null  float64
#  9   fuel_cost_per_unit_delivered  29523 non-null  float64
#  10  fuel_cost_per_mmbtu           29523 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 2.5+ MB
# Info None

# %% [markdown]
# ## Dataset Description
# - 'Record_id' : record id
#
# - 'Utility_id_ferc1': Utility id assigned by the FERC
#
# - 'Report_year': year of report
#
# - 'Plant_name_ferc1': the name of the plant
#
# - 'Fuel_type_code_pudl': the type of fuel
#
# - 'Fuel_unit': the unit of fuel
#
# - 'Fuel_qty_burned': the quantity of fuel burned
#
# - 'Fuel_mmbtu_per_unit': the measure of energy per unit
#
# - 'fuel_cost_per_unit_burned': the fuel cost per unit burned
#
# - 'Fuel_cost_per_unit_delivered': the cost of fuel delivered per unit
#
# - 'fuel_cost_per_mmbtu': the cost of fuel per mmbtu

# %% [markdown]
# ## Exploring the Dataset

# %%
print("ID of Utilities:",fuel['utility_id_ferc1'].unique(),"\n\nThe Number of Utlities:",fuel['utility_id_ferc1'].nunique())
# Out:
# ID of Utilities: [  1   2   4   6   7   9  10  11  12  15  16  17  20  24  26 191  31   8
#   42  43  44  46  50  51  54  55  38  73  81 127  19  36  61  63  64  68
#   70  72  74  75  77  79  80  85  96  97  98  99  27  30  52 135  69  87
#   88 121 122 102 193 194 125 126 128 129 130 131 132 134 137 141 142 143
#  145 117 146 150 151 157 114 115 118 161 162 163 164 166 169 170 173 176
#  177 179 182 185 186 187 188 189  33  89 200 201 204 208 159 119  25  49
#  108 155 100 107 144 116 136  67  82  95 133 138 148 190  56 113  32 120
#  147 160 175  22  39  62  76 101 124 154 156 174 195 104  14  57  41  45
#  149 213 210  29  94 230  71  21 202 244 226 227  65 171 181 221 266 245
#  270 276 203 271 283 281 285 287 196 288 294 262 178  58 432 315 403 449
#  452 192 454 513 514]
#
# The Number of Utlities: 185

# %%
print("Years for Which Data is Collected:",fuel['report_year'].unique(),"\n\nTotal Years:",fuel['report_year'].nunique(),"\n")
# Out:
# Years for Which Data is Collected: [1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018]
#
# Total Years: 25

# %%
print("The Types of plants:",fuel['plant_name_ferc1'].unique(),"\n\nTotal Number of Plants:",fuel['plant_name_ferc1'].nunique())
# Out:
# The Types of plants: ['rockport' 'rockport total plant' 'gorgas' ... 'airport unit 6'
#  'wyodak - bhp 20%' 'wygen 3 bhp 52%']
#
# Total Number of Plants: 2315

# %%
print("The Types of fuel:",fuel['fuel_type_code_pudl'].unique(),"\n\nTotal types of Fuel:",fuel['fuel_type_code_pudl'].nunique())
# Out:
# The Types of fuel: ['coal' 'gas' 'nuclear' 'oil' 'waste' 'other']
#
# Total types of Fuel: 6

# %%
print("The Types of fuel unit:",fuel['fuel_unit'].unique(),"\n\nTotal types of Fuel unit:",fuel['fuel_unit'].nunique())
# Out:
# The Types of fuel unit: ['ton' 'mcf' 'kgU' 'bbl' 'gramsU' nan 'mwdth' 'mmbtu' 'mwhth' 'gal']
#
# Total types of Fuel unit: 9

# %% [markdown]
# ## Visualising the Data

# %% [markdown]
# ### 1.1 Quantity of Fuel Burned in Respective Years

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20,6))
ax = sns.barplot(fuel['report_year'],fuel['fuel_qty_burned'])

# %% [markdown]
# ## Total Quantity of Fuel Burned in Respective Years

# %%
plt.figure(figsize=(20,6))
ax = fuel.groupby('report_year')['fuel_qty_burned'].sum().plot.bar()

# %% [markdown]
# ## Average Quantity of Fuel Burned in Years

# %%
plt.figure(figsize=(20,6))
ax = fuel.groupby('report_year')['fuel_qty_burned'].mean().plot.bar()

# %% [markdown]
# ## Total Energy Units Utilised in Respective Years

# %%
plt.figure(figsize=(20,6))
ax = fuel.groupby('report_year')['fuel_mmbtu_per_unit'].sum().plot.bar()

# %% [markdown]
# ## Average Energy Units Utilised in Respective Years

# %%
plt.figure(figsize=(20,6))
ax = fuel.groupby('report_year')['fuel_mmbtu_per_unit'].mean().plot.bar()

# %% [markdown]
# ## Total Fuel Cost for Burned Units in Respective Years

# %%
plt.figure(figsize=(20,6))
ax =fuel.groupby('report_year')['fuel_cost_per_unit_burned'].sum().plot.bar()

# %% [markdown]
# ## Total Fuel Cost for Burned Units in Respective Years

# %%
plt.figure(figsize=(20,6))
ax =fuel.groupby('report_year')['fuel_cost_per_unit_burned'].mean().plot.bar()

# %% [markdown]
# ##  Fuel Quantity Burned

# %%
plt.figure(figsize=(8,6))
ax = sns.barplot(fuel['fuel_type_code_pudl'],fuel['fuel_qty_burned'])

# %% [markdown]
# ### 1.2 Total Fuel Burned By  Fuel Type

# %%
plt.figure(figsize=(8,6))
ax = fuel.groupby('fuel_type_code_pudl')['fuel_qty_burned'].sum().plot.bar()

# %% [markdown]
# ### 1.3 Quantity of Fuel Burned By  Fuel Unit

# %%
plt.figure(figsize=(10,6))
ax = sns.barplot(fuel['fuel_unit'],fuel['fuel_qty_burned'])

# %% [markdown]
# ## Total Quantity of Fuel Burned By  Fuel Unit

# %%
plt.figure(figsize=(8,6))
ax = fuel.groupby('fuel_unit')['fuel_qty_burned'].sum().plot.bar()

# %% [markdown]
# ### 1.4 Quantity of Fuel Burned by Top 10 Plants

# %%
fuel_plant = fuel['plant_name_ferc1']
fuel_plant = fuel_plant[:10,]
plt.figure(figsize=(20,4))
ax = sns.barplot(fuel_plant,fuel['fuel_qty_burned'])

# %% [markdown]
# ### 1.5 Pairplot of the Data

# %%
ax = sns.pairplot(fuel)

# %%
df = fuel.groupby('plant_name_ferc1')['fuel_qty_burned'].sum().sort_values(ascending=False)
df = df[:10]
df
# Out:
# plant_name_ferc1
# sabine                  1.527383e+09
# sanford                 1.293785e+09
# ninemile point          1.290046e+09
# martin                  1.142015e+09
# hines energy complex    1.133638e+09
# west county             1.121198e+09
# lauderdale              1.044482e+09
# ft. myers               1.038134e+09
# arkansas nuclear one    8.935443e+08
# manatee                 8.257577e+08
# Name: fuel_qty_burned, dtype: float64
